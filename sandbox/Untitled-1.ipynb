# %%
import pandas as pd
import google.generativeai as genai
import os

# %%
data = {
    'Français': ["Bonjour", "Merci", "Comment tu t'appelles ?", "Où sont les toilettes ?", "Que fais tu dans la vie ?"],
    'Anglais': [None, None, None, None, None],
    'Espagnol': [None, None, None, None, None],
    'Italien': [None, None, None, None, None]
}

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#                     Français Anglais Espagnol Italien
# 0                    Bonjour    None     None    None
# 1                      Merci    None     None    None
# 2    Comment tu t'appelles ?    None     None    None
# 3    Où sont les toilettes ?    None     None    None
# 4  Que fais tu dans la vie ?    None     None    None

# %%
GEMINI_API_KEY="AIzaSyAoTItMi5qLpynmwdq7v-xNkFCRFPYUIxw"

# %%
def translator(prompt, target_language):
    try:
        genai.configure(api_key=os.environ["GEMINI_API_KEY"])
        prompt = f"traduis {prompt} en {target_language}, la réponse ne doit contenir que la traduction"
        model = genai.GenerativeModel("gemini-1.5-flash")
        response = model.generate_content(prompt)

        return response.text.strip() 
    except Exception as e:
        print(f"Erreur pendant la traduction de '{prompt}' vers '{target_language}': {e}")
        return None

# %%
try:
    genai.configure(api_key=os.environ["GEMINI_API_KEY"])
    model = genai.GenerativeModel("gemini-1.5-flash")
    response = model.generate_content("traduis Bonjour en anglais")
    print("Connexion réussie :", response.text)
except Exception as e:
    print("Erreur de connexion :", e)
# Out:
# Erreur de connexion : 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]

# %%
for language in ["Anglais", "Espagnol", "Italien"]:
    for i, text in enumerate(data["Français"]):
        translated_text = translator(text, language.lower())
        data[language][i] = translated_text
# Out:
# Erreur pendant la traduction de 'traduis Bonjour en anglais, la réponse ne doit contenir que la traduction' vers 'anglais': 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]
# Erreur pendant la traduction de 'traduis Merci en anglais, la réponse ne doit contenir que la traduction' vers 'anglais': 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]
# ...

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe.to_csv("all_translation.csv", index=False, sep=";")

# %%
dataframe
# Out:
#                     Français Anglais Espagnol Italien
# 0                    Bonjour    None     None    None
# 1                      Merci    None     None    None
# 2    Comment tu t'appelles ?    None     None    None
# 3    Où sont les toilettes ?    None     None    None
# 4  Que fais tu dans la vie ?    None     None    None

# %% [markdown]
# Bonjour, je vous écrit ce message car je ne rencontre que des erreurs qui non aucun lieu d'être car un de mes camarade à essayer de son coté et mon code fonctionner donc je ne comprend pas mes erreurs mes bref.
# Il est actuellement 17h, je suis reveiller depuis 4h et je n'est pas arréter de la journée, et je ne suis pas là ce soir, donc j'arrète de me prendre la tête je vais vous mettre les erreurs en dessous au cas où mais je suis quasiment sur que cela fonctionne ou alors il ne manque rien pour que cela fonctionne
# Bonne journée/soirée à vous
#
#
# Fonction try :
# ```
# Erreur de connexion : 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]
# ```
#
#
#
# Fonction for :
# ```
# Erreur pendant la traduction de 'traduis Bonjour en anglais, la réponse ne doit contenir que la traduction' vers 'anglais': 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]
# Erreur pendant la traduction de 'traduis Merci en anglais, la réponse ne doit contenir que la traduction' vers 'anglais': 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]
# Erreur pendant la traduction de 'traduis Comment tu t'appelles ? en anglais, la réponse ne doit contenir que la traduction' vers 'anglais': 400 API key not valid. Please pass a valid API key. [reason: "API_KEY_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "service"
#   value: "generativelanguage.googleapis.com"
# }
# , locale: "en-US"
# ...
# }
# , locale: "en-US"
# message: "API key not valid. Please pass a valid API key."
# ]
# ```
#
# Ma clé api :
# ```
# AIzaSyAoTItMi5qLpynmwdq7v-xNkFCRFPYUIxw
# ```
